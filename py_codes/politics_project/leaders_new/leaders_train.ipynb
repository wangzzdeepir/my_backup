# %%
import os
os.chdir('/home/deep/develop/caffe/')
# !ls
# !examples/mytask_leaders/train_caffenet.sh
# Out:
# build		 data	     INSTALL.md		      models
# caffe.cloc	 distribute  LICENSE		      python
# cmake		 docker      Makefile		      README.md
# CMakeLists.txt	 docs	     Makefile.config	      scripts
# CONTRIBUTING.md  examples    Makefile.config.example  src
# CONTRIBUTORS.md  include     matlab		      tools
# I1115 22:19:47.347092  5921 caffe.cpp:217] Using GPUs 0
# I1115 22:19:47.536137  5921 caffe.cpp:222] GPU 0: GeForce GTX 960M
# I1115 22:19:47.665998  5921 solver.cpp:48] Initializing solver from parameters:
# test_iter: 100
# test_interval: 10
# base_lr: 1e-05
# display: 10
# max_iter: 1000
# lr_policy: "step"
# gamma: 0.5
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 100
# snapshot: 500
# snapshot_prefix: "models/bvlc_reference_caffenet_leaders/caffenet_train"
# solver_mode: GPU
# device_id: 0
# net: "models/bvlc_reference_caffenet_leaders/train_val.prototxt"
# train_state {
#   level: 0
#   stage: ""
# }
# ...
